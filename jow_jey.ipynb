# %% [markdown]
# <a href="https://colab.research.google.com/github/jowjey/jowjey/blob/main/jow_jey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Conheça o Colab</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>&#40;Novidade&#41; Teste a API Gemini</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
pip install pyttsx3

# %%
pip install SpeechRecognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 35.8 MB/s eta 0:00:00
# ...

# %%
pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=a8ef0c4bf6b466c57a6588c4e05d5c6ad3de0fcdf1d84257523d3939c3d4b4cc
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %%
import pyttsx3
import speech_recognition as sr
import wikipedia
import webbrowser
import os
import datetime

# Configuração da engine de síntese de voz
def configurar_engine():
    engine = pyttsx3.init()
    vozes = engine.getProperty('voices')
    engine.setProperty('voice', vozes[1].id)  # Seleciona uma voz feminina
    return engine

# Função para falar
def falar(texto):
    engine.say(texto)
    engine.runAndWait()

# Função para reconhecimento de voz
def ouvir():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Ouvindo...")
        r.pause_threshold = 1
        audio = r.listen(source)
    try:
        print("Reconhecendo...")
        query = r.recognize_google(audio, language='pt-BR')
        print(f"Você disse: {query}\n")
    except Exception as e:
        print("Repita, por favor...")
        return "None"
    return query

# Função para desejar boas-vindas
def dar_boas_vindas():
    hora = int(datetime.datetime.now().hour)
    if hora >= 0 and hora < 12:
        falar("Bom dia!")
    elif hora >= 12 and hora < 18:
        falar("Boa tarde!")
    else:
        falar("Boa noite!")
    falar("Eu sou o Jow Jey. Como posso ajudar você hoje?")

# Função principal
def main():
    dar_boas_vindas()
    while True:
        query = ouvir().lower()
        if 'wikipedia' in query:
            falar('Pesquisando no Wikipedia...')
            query = query.replace("wikipedia", "")
            resultados = wikipedia.summary(query, sentences=2)
            falar("De acordo com o Wikipedia")
            print(resultados)
            falar(resultados)
        elif 'abrir youtube' in query:
            webbrowser.open("youtube.com")
        elif 'abrir google' in query:
            webbrowser.open("google.com")
        elif 'hora' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            falar(f"Agora são {strTime}")
        elif 'desligar' in query:
            falar("Até mais! Desligando...")
            break

if __name__ == "__main__":
    engine = configurar_engine()
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# /usr/lib/python3.10/weakref.py in __getitem__(self, key)
#     136             self._commit_removals()
# --> 137         o = self.data[key]()
#     138         if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-01c107ad0519> in <cell line: 70>()
#      69
#      70 if __name__ == "__main__":
# ---> 71     engine = configurar_engine()
#      72     main()
#
# <ipython-input-5-01c107ad0519> in configurar_engine()
#       8 # Configuração da engine de síntese de voz
# ...

# %%
sudo apt-get install espeak

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Configurando a engine de síntese de voz
def configurar_engine():
    engine = pyttsx3.init()
    vozes = engine.getProperty('voices')
    engine.setProperty('voice', vozes[0].id)  # Seleciona uma voz masculina
    engine.setProperty('rate', 150)  # Define a velocidade de fala (palavras por minuto)
    return engine

# Função para falar
def falar(texto):
    engine.say(texto)
    engine.runAndWait()

# Função para reconhecimento de voz
def ouvir():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Ouvindo...")
        r.pause_threshold = 1
        audio = r.listen(source)
    try:
        print("Reconhecendo...")
        query = r.recognize_google(audio, language='pt-BR')
        print(f"Você disse: {query}\n")
    except Exception as e:
        print("Repita, por favor...")
        return "None"
    return query

# Função para desejar boas-vindas
def dar_boas_vindas():
    hora = datetime.datetime.now().hour
    if hora >= 0 and hora < 12:
        falar("Bom dia! Como posso ajudar você?")
    elif hora >= 12 and hora < 18:
        falar("Boa tarde! Como posso ajudar você?")
    else:
        falar("Boa noite! Como posso ajudar você?")

# Função principal
def main():
    dar_boas_vindas()
    while True:
        query = ouvir().lower()
        # Lógica para comandos específicos
        if 'wikipedia' in query:
            falar('Pesquisando no Wikipedia...')
            query = query.replace("wikipedia", "")
            resultados = wikipedia.summary(query, sentences=2)
            falar("De acordo com o Wikipedia")
            print(resultados)
            falar(resultados)
        elif 'abrir youtube' in query:
            webbrowser.open("youtube.com")
        elif 'abrir google' in query:
            webbrowser.open("google.com")
        elif 'hora' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            falar(f"Agora são {strTime}")
        elif 'desligar' in query:
            falar("Até mais! Desligando...")
            break

if __name__ == "__main__":
    engine = configurar_engine()
    main()

# %%
import datetime
import wikipedia
import webbrowser

# Função para exibir o menu
def exibir_menu():
    print("\nMenu:")
    print("1. Pesquisar na Wikipedia")
    print("2. Abrir o YouTube")
    print("3. Abrir o Google")
    print("4. Verificar a hora")
    print("5. Desligar")

# Função para pesquisar na Wikipedia
def pesquisar_wikipedia():
    print("Pesquisando na Wikipedia...")
    termo = input("Digite o que deseja pesquisar: ")
    resultados = wikipedia.summary(termo, sentences=2)
    print("De acordo com a Wikipedia:")
    print(resultados)

# Função para abrir o YouTube
def abrir_youtube():
    print("Abrindo o YouTube...")
    webbrowser.open("https://www.youtube.com")

# Função para abrir o Google
def abrir_google():
    print("Abrindo o Google...")
    webbrowser.open("https://www.google.com")

# Função para verificar a hora
def verificar_hora():
    hora_atual = datetime.datetime.now().strftime("%H:%M:%S")
    print("Agora são", hora_atual)

# Função principal
def main():
    print("Olá! Eu sou o Jow Jey.")
    print("Como posso ajudar você hoje?")

    while True:
        exibir_menu()
        opcao = input("Selecione uma opção: ")

        if opcao == "1":
            pesquisar_wikipedia()
        elif opcao == "2":
            abrir_youtube()
        elif opcao == "3":
            abrir_google()
        elif opcao == "4":
            verificar_hora()
        elif opcao == "5":
            print("Até mais! Desligando...")
            break
        else:
            print("Opção inválida. Por favor, selecione uma opção válida.")

if __name__ == "__main__":
    main()

# %%
import os

# Função para verificar e aplicar atualizações
def verificar_atualizacoes():
    # Lógica para verificar atualizações (por exemplo, verificar um servidor web)
    atualizacoes_disponiveis = True  # Simula a presença de atualizações disponíveis

    if atualizacoes_disponiveis:
        print("Atualizações disponíveis. Atualizando...")
        # Lógica para baixar e aplicar as atualizações (por exemplo, usar git pull)
        os.system("git pull")  # Simula o comando para atualizar o código usando git
        print("Atualizações aplicadas com sucesso.")
    else:
        print("Nenhuma atualização disponível.")

# Função principal
def main():
    print("Olá! Eu sou o Jow Jey.")
    print("Como posso ajudar você hoje?")

    while True:
        # Lógica para processar as solicitações do usuário
        # Por exemplo, exibir um menu, ouvir a entrada do usuário e responder

        verificar_atualizacoes()  # Verificar atualizações a cada iteração

if __name__ == "__main__":
    main()

# %%
pip install transformers pyttsx3 wikipedia

# %%
pip install pyttsx3
pip install SpeechRecognition
pip install wikipedia

# %%
python3 assistente.py

# %%
python3 assistente.py
# Out:
#   File "<ipython-input-6-e721d8ab263a>", line 1
#     python3 assistente.py
#             ^
# SyntaxError: invalid syntax

# %%
sudo apt-get update
sudo apt-get install espeak

# !pip install pyttsx3==2.90

import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
#   File "<ipython-input-7-ab61f994fd56>", line 1
#     sudo apt-get update
#          ^
# SyntaxError: invalid syntax

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# /usr/lib/python3.10/weakref.py in __getitem__(self, key)
#     136             self._commit_removals()
# --> 137         o = self.data[key]()
#     138         if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-e106d4d03edc> in <cell line: 12>()
#      10
#      11 # Inicialização do módulo de síntese de voz
# ---> 12 engine = pyttsx3.init()
#      13
#      14 # Configuração da voz (opcional)
#
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
# ...

# %%
sudo apt-get update
sudo apt-get install espeak
# Out:
#   File "<ipython-input-9-bade93581317>", line 1
#     sudo apt-get update
#          ^
# SyntaxError: invalid syntax

# %%
# !apt-get update
# !apt-get install espeak
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [713 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,907 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,786 kB]
# ...

# %%
pip uninstall pyttsx3
pip install pyttsx3
# Out:
#   File "<ipython-input-11-9e2ff663a91e>", line 1
#     pip uninstall pyttsx3
#         ^
# SyntaxError: invalid syntax

# %%
# !pip uninstall pyttsx3
# Out:
# Found existing installation: pyttsx3 2.90
# Uninstalling pyttsx3-2.90:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/pyttsx3-2.90.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/pyttsx3/*
# Proceed (Y/n)? y
#   Successfully uninstalled pyttsx3-2.90

# %%
# !pip install pyttsx3==2.90
# Out:
# ...
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# ...

# %%
import datetime
import wikipedia
import webbrowser

def speak(text):
    print(text)

def take_command():
    command = input("Como posso ajudar você? ")
    return command

def run_jarvis():
    while True:
        command = take_command().lower()

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            speak(f'Agora são {hora}')
        elif 'pesquisar' in command:
            speak('O que devo pesquisar?')
            search_query = take_command()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                speak(info)
            except wikipedia.exceptions.DisambiguationError as e:
                speak("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'sair' in command or 'parar' in command:
            speak('Até logo!')
            break
        else:
            speak('Desculpe, não entendi o comando. Pode repetir?')

run_jarvis()
# Out:
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# Desculpe, não entendi o comando. Pode repetir?
# ...

# %%
pip install pyfirmata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)


def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
        speak('Good Morning Sir')
    elif hour>=12 and hour<18:
        speak('Good Afternoon sir')
    else:
        speak('Good Evening sir')

        speak('I am Jarvis')
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print('Listening...')
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print('Recognizing...')
        query = r.recognize_google(audio, language='en')
        print(f"User said: {query}\n")

    except Exception as e:

        print('say that again pls sir')
        return "None"
    return query


if __name__ == "__main__":
   wishMe()
   while True:
        query = takeCommand().lower()
   #executing task based on query


   if 'wikipedia' in query:
       speak('Searching wikipedia')
       query = query.replace("wikipedia", "")
       results = wikipedia.summary(query, sentences=2)
       speak("According to Wikipedia")
       speak(results)

   elif 'open YouTube' in query:
       webbrowser.open_new_tab("https:\\www.youtube.com")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# /usr/lib/python3.10/weakref.py in __getitem__(self, key)
#     136             self._commit_removals()
# --> 137         o = self.data[key]()
#     138         if o is None:
#
# KeyError: 'sapi5'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-7d1c4a12737c> in <cell line: 7>()
#       5 import webbrowser
#       6
# ----> 7 engine = pyttsx3.init('sapi5')
#       8 voices = engine.getProperty('voices')
#       9 engine.setProperty('voice', voices[1].id)
#
# ...

# %%
git clone https://github.com/tino/pyFirmata
cd pyFirmata
python setup.py install
# Out:
#   File "<ipython-input-17-e476e282ff51>", line 1
#     git clone https://github.com/tino/pyFirmata
#         ^
# SyntaxError: invalid syntax

# %%
>>> from pyfirmata import Arduino, util
>>> board = Arduino('/dev/tty.usbserial-A6008rIF')
>>> board.digital[13].write(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/serial/serialposix.py in open(self)
#     321         try:
# --> 322             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/tty.usbserial-A6008rIF'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-18-19f5956f0dea> in <cell line: 2>()
#       1 from pyfirmata import Arduino, util
# ----> 2 board = Arduino('/dev/tty.usbserial-A6008rIF')
#       3 board.digital[13].write(1)
#
# /usr/local/lib/python3.10/dist-packages/pyfirmata/__init__.py in __init__(self, *args, **kwargs)
#      17         args = list(args)
# ...

# %%
it = util.Iterator(board)
it.start()
board.analog[0].enable_reporting()
board.analog[0].read()
0.661440304938
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-eb473ba4d7a8> in <cell line: 1>()
# ----> 1 it = util.Iterator(board)
#       2 it.start()
#       3 board.analog[0].enable_reporting()
#       4 board.analog[0].read()
#       5 0.661440304938
#
# NameError: name 'board' is not defined

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-6b92fc1acfac> in <cell line: 1>()
# ----> 1 import openai
#       2
#       3 # Configure a sua chave de API do OpenAI
#       4 openai.api_key = 'sua-chave-de-api'
#       5
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from gpt4 import GPT4

# Initialize the GPT-4 model
model = GPT4.from_pretrained('gpt-4')

# Set the input and output text
input_text = "What is your name?"
output_text = "My name is Leo."

# Generate the response
response = model.generate(input_text)

# Print the response
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-0de59ea04490> in <cell line: 1>()
# ----> 1 from gpt4 import GPT4
#       2
#       3 # Initialize the GPT-4 model
#       4 model = GPT4.from_pretrained('gpt-4')
#       5
#
# ModuleNotFoundError: No module named 'gpt4'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pyttsx3==2.71
# Out:
# ...
#   Attempting uninstall: pyttsx3
#     Found existing installation: pyttsx3 2.90
#     Uninstalling pyttsx3-2.90:
#       Successfully uninstalled pyttsx3-2.90
# ...

# %%
# !pip install pyttsx3==2.90
# Out:
# ...
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# ...
#   Attempting uninstall: pyttsx3
#     Found existing installation: pyttsx3 2.71
#     Uninstalling pyttsx3-2.71:
#       Successfully uninstalled pyttsx3-2.71
# ...

# %%
pip install pyttsx3==2.71
# Out:
# ...
#   Using cached pyttsx3-2.71-py3-none-any.whl (39 kB)
# ...
#   Attempting uninstall: pyttsx3
#     Found existing installation: pyttsx3 2.90
#     Uninstalling pyttsx3-2.90:
#       Successfully uninstalled pyttsx3-2.90
# ...

# %%
# !python3 assistente.py
# Out:
# python3: can't open file '/content/assistente.py': [Errno 2] No such file or directory

# %% [markdown]
# Se você já conhece bem o Colab, confira este vídeo para saber mais sobre as tabelas interativas, a visualização do histórico de código executado e o Palette de comandos.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Miniatura de um vídeo mostrando três recursos interessantes do Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>O que é o Colab?</h2>
# </div>
#
# O Colab, ou "Colaboratory", permite escrever e executar Python no navegador e conta com o seguinte:
# - Nenhuma configuração necessária
# - Acesso a GPUs sem custo financeiro
# - Compartilhamento fácil
#
# Você pode ser um <strong>estudante</strong>, um <strong>cientista de dados</strong> ou um <strong>pesquisador de IA</strong>, o Colab pode facilitar seu trabalho. Assista ao vídeo <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introdução ao Colab</a> para saber mais ou simplesmente comece a usá-lo abaixo!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Vamos começar</strong>
# </div>
#
# O documento que você está lendo não é uma página da Web estática, mas sim um ambiente interativo chamado <strong>notebook Colab</strong> que permite escrever e executar código.
#
# Por exemplo, aqui está uma <strong>célula de código</strong> com um breve script Python que calcula um valor, armazena-o em uma variável e imprime o resultado:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Para executar o código na célula acima, clique nela e depois pressione o botão Play à esquerda do código ou use o atalho do teclado "Command/Ctrl+Enter". Para editar o código, basta clicar na célula e começar a editar.
#
# As variáveis definidas em uma célula podem ser usadas mais tarde em outras células:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Os notebooks do Colab permitem combinar <strong>código executável</strong> e <strong>rich text</strong> em um só documento, além de <strong>imagens</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> e muito mais. Quando você cria seus próprios notebooks do Colab, eles são armazenados na sua conta do Google Drive. É possível compartilhar os notebooks do Colab facilmente com colegas de trabalho ou amigos e permitir que eles façam comentários ou até editem o documento. Para saber mais, consulte a <a href="/notebooks/basic_features_overview.ipynb">Visão Geral do Colab</a>. Para criar um novo bloco do Colab, use o menu Arquivo acima ou acesse o seguinte: <a href="http://colab.research.google.com#create=true">criar um novo bloco do Colab</a>.
#
# Os notebooks do Colab são notebooks do Jupyter hospedados no Colab. Para saber mais sobre o projeto Jupyter, acesse <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Ciência de dados
# </div>
#
# Com o Colab, você pode aproveitar todo o potencial das conhecidas bibliotecas Python para analisar e ver dados. A célula de códigos abaixo usa <strong>numpy</strong> para gerar dados aleatórios e <strong>matplotlib</strong> para visualizá-los. Para editar o código, basta clicar na célula e começar a editar.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-6b92fc1acfac> in <cell line: 1>()
# ----> 1 import openai
#       2
#       3 # Configure a sua chave de API do OpenAI
#       4 openai.api_key = 'sua-chave-de-api'
#       5
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install openai4
# Out:
# ERROR: Could not find a version that satisfies the requirement openai4 (from versions: none)
# ERROR: No matching distribution found for openai4

# %%
pip install openai

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-33-e106d4d03edc> in <cell line: 58>()
#      57
#      58 while True:
# ---> 59     run_jarvis()
#      60 import pyttsx3
#      61 import speech_recognition as sr
#
# <ipython-input-33-e106d4d03edc> in run_jarvis()
#      35
#      36 def run_jarvis():
# ---> 37     command = take_command()
#      38     if 'hora' in command:
#      39         hora = datetime.datetime.now().strftime('%H:%M')
#
# <ipython-input-33-e106d4d03edc> in take_command()
#      32     except:
#      33         pass
# ---> 34     return command
#      35
#      36 def run_jarvis():
#
# UnboundLocalError: local variable 'command' referenced before assignment

# %%
pip install SpeechRecognition

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# Como posso ajudar você? ola
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-35-6b92fc1acfac> in <cell line: 43>()
#      41             print(response)
#      42
# ---> 43 run_jarvis()
#      44 import openai
#      45
#
# <ipython-input-35-6b92fc1acfac> in run_jarvis()
#      38             break
#      39         else:
# ---> 40             response = gpt4_prompt(command)
#      41             print(response)
#      42
#
# <ipython-input-35-6b92fc1acfac> in gpt4_prompt(prompt)
#       5
#       6 def gpt4_prompt(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ...

# %%
pip install openai==0.28

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# Como posso ajudar você? oi
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-37-6b92fc1acfac> in <cell line: 43>()
#      41             print(response)
#      42
# ---> 43 run_jarvis()
#      44 import openai
#      45
#
# <ipython-input-37-6b92fc1acfac> in run_jarvis()
#      38             break
#      39         else:
# ---> 40             response = gpt4_prompt(command)
#      41             print(response)
#      42
#
# <ipython-input-37-6b92fc1acfac> in gpt4_prompt(prompt)
#       5
#       6 def gpt4_prompt(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ...

# %%
openai migrate

# %%
openai
# Out:
# <module 'openai' from '/usr/local/lib/python3.10/dist-packages/openai/__init__.py'>

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def conversa_com_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

# Exemplo de conversa simples
pergunta = "Qual é o sentido da vida?"
resposta = conversa_com_gpt3(pergunta)
print("GPT-3:", resposta)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-40-21d387be9a10> in <cell line: 16>()
#      14 # Exemplo de conversa simples
#      15 pergunta = "Qual é o sentido da vida?"
# ---> 16 resposta = conversa_com_gpt3(pergunta)
#      17 print("GPT-3:", resposta)
#
# <ipython-input-40-21d387be9a10> in conversa_com_gpt3(prompt)
#       5
#       6 def conversa_com_gpt3(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...

# %%
pip install openai==0.28

# %%
pip install openai

# %% [markdown]
# É possível importar para os notebooks do Colab os dados da sua conta do Google Drive, como planilhas. Também é possível importar do GitHub e de muitas outras fontes. Para saber mais sobre como importar dados e como o Colab pode ser usado para a ciência de dados, consulte o link abaixo em <a href="#working-with-data">Como trabalhar com dados</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# Com o Colab, é possível importar um conjunto de dados de imagem, treinar um classificador de imagens dentro dele e avaliar o modelo, tudo com apenas <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">algumas linhas de código</a>. Os notebooks do Colab executam código dos servidores em nuvem do Google. Isso significa que você pode tirar proveito da potência de hardware do Google, como <a href="#using-accelerated-hardware">GPUs e TPUs</a>, independentemente da potência da sua máquina. Você só precisa de um navegador.

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.15.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.67906   ,  0.5097161 ,  0.48607472,  0.07675117,  0.62150854,
#         -0.03670141, -0.19457954,  0.37788576, -0.438923  , -0.02106064]],
#       dtype=float32)

# %%
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.04367891, 0.1434005 , 0.14005008, 0.09300716, 0.16036202,
#         0.08303183, 0.07090534, 0.12568906, 0.05553439, 0.08434071]],
#       dtype=float32)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
loss_fn(y_train[:1], predictions).numpy()
# Out:
# 2.4885314

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2989 - accuracy: 0.9133
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1446 - accuracy: 0.9569
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1073 - accuracy: 0.9675
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0874 - accuracy: 0.9731
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0755 - accuracy: 0.9761

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0731 - accuracy: 0.9789 - 769ms/epoch - 2ms/step
# [0.07313738018274307, 0.9789000153541565]

# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
probability_model(x_test[:5])
# Out:
# <tf.Tensor: shape=(5, 10), dtype=float32, numpy=
# array([[3.83348197e-06, 3.21729177e-09, 2.26984441e-04, 5.06700482e-04,
#         4.67142297e-11, 1.38404960e-06, 2.98116024e-13, 9.99191344e-01,
#         3.19678361e-06, 6.64595063e-05],
#        [3.48872078e-07, 3.13289434e-04, 9.99546349e-01, 1.15522686e-04,
#         6.81063170e-13, 1.96389392e-05, 1.55768319e-07, 1.84701265e-11,
#         4.66737129e-06, 1.23624479e-11],
#        [4.40721749e-07, 9.97239470e-01, 9.38631536e-04, 3.51154631e-05,
#         1.19065269e-04, 2.45831889e-05, 6.99541561e-05, 1.50604220e-03,
#         6.62438324e-05, 4.94759433e-07],
#        [9.99971271e-01, 1.84926467e-11, 9.91936213e-06, 3.41130288e-08,
#         4.22765556e-09, 4.65544900e-07, 1.71050010e-06, 2.69202502e-07,
#         7.02195690e-10, 1.62876149e-05],
#        [7.25692507e-06, 2.68197482e-07, 9.50645044e-05, 2.35886176e-07,
#         9.92501736e-01, 5.67754842e-06, 2.12725718e-05, 7.97297398e-05,
# ...

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# Como posso ajudar você? oi
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-55-6b92fc1acfac> in <cell line: 43>()
#      41             print(response)
#      42
# ---> 43 run_jarvis()
#      44 import openai
#      45
#
# <ipython-input-55-6b92fc1acfac> in run_jarvis()
#      38             break
#      39         else:
# ---> 40             response = gpt4_prompt(command)
#      41             print(response)
#      42
#
# <ipython-input-55-6b92fc1acfac> in gpt4_prompt(prompt)
#       5
#       6 def gpt4_prompt(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ...

# %%
pip install openai==0.28

# %%
pip install jarvis
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jarvis: filename=jarvis-0.1.9-py3-none-any.whl size=40469 sha256=2e2d88e2ba8aec027fc4fa64664201bcd076898a74005f692b455e36190dbcba
#   Stored in directory: /root/.cache/pip/wheels/ff/47/23/3737fda5e4bde40a162e78dbb3cd7a2bf569794665aa284c52
# Successfully built jarvis
# ...

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def conversa_com_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

# Exemplo de conversa simples
pergunta = "Qual é o sentido da vida?"
resposta = conversa_com_gpt3(pergunta)
print("GPT-3:", resposta)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-58-21d387be9a10> in <cell line: 16>()
#      14 # Exemplo de conversa simples
#      15 pergunta = "Qual é o sentido da vida?"
# ---> 16 resposta = conversa_com_gpt3(pergunta)
#      17 print("GPT-3:", resposta)
#
# <ipython-input-58-21d387be9a10> in conversa_com_gpt3(prompt)
#       5
#       6 def conversa_com_gpt3(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...

# %%
pip install jarvis gpt4

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def conversa_com_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

# Exemplo de conversa simples
pergunta = "Qual é o sentido da vida?"
resposta = conversa_com_gpt3(pergunta)
print("GPT-3:", resposta)

# %%
pip install jarvis

# %%
run jarvis.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'jarvis.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-60-5c7bd1c96491> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'jarvis.py')
#
# ...

# %%
# %run jarvis.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'jarvis.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-61-5c7bd1c96491> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'jarvis.py')
#
# ...

# %%
# %run /caminho/completo/para/jarvis.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'/caminho/completo/para/jarvis.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-62-522f18c47da9> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '/caminho/completo/para/jarvis.py')
#
# ...

# %%
# %run /home/usuario/meu_projeto/jarvis.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'/home/usuario/meu_projeto/jarvis.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-63-90e217203943> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', '/home/usuario/meu_projeto/jarvis.py')
#
# ...

# %%
create jarvis.py
# Out:
#   File "<ipython-input-64-4ac8386f0e3f>", line 1
#     create jarvis.py
#            ^
# SyntaxError: invalid syntax

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# Como posso ajudar você? se atualize
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-65-6b92fc1acfac> in <cell line: 43>()
#      41             print(response)
#      42
# ---> 43 run_jarvis()
#      44 import openai
#      45
#
# <ipython-input-65-6b92fc1acfac> in run_jarvis()
#      38             break
#      39         else:
# ---> 40             response = gpt4_prompt(command)
#      41             print(response)
#      42
#
# <ipython-input-65-6b92fc1acfac> in gpt4_prompt(prompt)
#       5
#       6 def gpt4_prompt(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
# ...

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-66-e106d4d03edc> in <cell line: 58>()
#      57
#      58 while True:
# ---> 59     run_jarvis()
#      60 import pyttsx3
#      61 import speech_recognition as sr
#
# <ipython-input-66-e106d4d03edc> in run_jarvis()
#      35
#      36 def run_jarvis():
# ---> 37     command = take_command()
#      38     if 'hora' in command:
#      39         hora = datetime.datetime.now().strftime('%H:%M')
#
# <ipython-input-66-e106d4d03edc> in take_command()
#      32     except:
#      33         pass
# ---> 34     return command
#      35
#      36 def run_jarvis():
#
# UnboundLocalError: local variable 'command' referenced before assignment

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-67-e106d4d03edc> in <cell line: 58>()
#      57
#      58 while True:
# ---> 59     run_jarvis()
#      60 import pyttsx3
#      61 import speech_recognition as sr
#
# <ipython-input-67-e106d4d03edc> in run_jarvis()
#      35
#      36 def run_jarvis():
# ---> 37     command = take_command()
#      38     if 'hora' in command:
#      39         hora = datetime.datetime.now().strftime('%H:%M')
#
# <ipython-input-67-e106d4d03edc> in take_command()
#      32     except:
#      33         pass
# ---> 34     return command
#      35
#      36 def run_jarvis():
#
# UnboundLocalError: local variable 'command' referenced before assignment

# %%
# !pip install wikipedia

# %%
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
import openai

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def gpt4_prompt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
        prompt=prompt,
        max_tokens=100
    )
    return response.choices[0].text.strip()

def run_jarvis():
    while True:
        command = input("Como posso ajudar você? ")

        if 'hora' in command:
            hora = datetime.datetime.now().strftime('%H:%M')
            print(f'Agora são {hora}')
        elif 'pesquisar' in command:
            print('O que devo pesquisar?')
            search_query = input()
            wikipedia.set_lang('pt')
            try:
                info = wikipedia.summary(search_query, sentences=1)
                print(info)
            except wikipedia.exceptions.DisambiguationError as e:
                print("Parece que há ambiguidade na sua pesquisa. Por favor, seja mais específico.")
        elif 'abrir youtube' in command:
            webbrowser.open("https://www.youtube.com/")
        elif 'abrir google' in command:
            webbrowser.open("https://www.google.com/")
        elif 'abrir stack overflow' in command:
            webbrowser.open("https://stackoverflow.com/")
        elif 'sair' in command or 'parar' in command:
            print('Até logo!')
            break
        else:
            response = gpt4_prompt(command)
            print(response)

run_jarvis()
# Out:
# Como posso ajudar você? se atualizee
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-69-6b92fc1acfac> in <cell line: 43>()
#      41             print(response)
#      42
# ---> 43 run_jarvis()
#      44 import openai
#      45
#
# <ipython-input-69-6b92fc1acfac> in run_jarvis()
#      38             break
#      39         else:
# ---> 40             response = gpt4_prompt(command)
#      41             print(response)
#      42
#
# <ipython-input-69-6b92fc1acfac> in gpt4_prompt(prompt)
#       5
#       6 def gpt4_prompt(prompt):
# ----> 7     response = openai.Completion.create(
#       8         engine="text-davinci-002",  # Ou outro engine adequado para o GPT-4
#       9         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
# ...

# %%
pip install openai pyttsx3

# %%
import openai
import pyttsx3

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def conversa_com_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

def resposta_com_voz(texto):
    engine = pyttsx3.init()
    engine.say(texto)
    engine.runAndWait()

# Exemplo de conversa simples
pergunta = "Qual é o sentido da vida?"
resposta = conversa_com_gpt3(pergunta)
print("GPT-3:", resposta)

# Responder com voz
resposta_com_voz(resposta)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-71-491273ec81d4> in <cell line: 22>()
#      20 # Exemplo de conversa simples
#      21 pergunta = "Qual é o sentido da vida?"
# ---> 22 resposta = conversa_com_gpt3(pergunta)
#      23 print("GPT-3:", resposta)
#      24
#
# <ipython-input-71-491273ec81d4> in conversa_com_gpt3(prompt)
#       6
#       7 def conversa_com_gpt3(prompt):
# ----> 8     response = openai.Completion.create(
#       9         engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
#      10         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...

# %%
import openai
import pyttsx3

# Configure a sua chave de API do OpenAI
openai.api_key = 'sua-chave-de-api'

def conversa_com_gpt3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
        prompt=prompt,
        max_tokens=50
    )
    return response.choices[0].text.strip()

def resposta_com_voz(texto):
    engine = pyttsx3.init()
    engine.say(texto)
    engine.runAndWait()

# Exemplo de conversa simples
pergunta = "Qual é o sentido da vida?"
resposta = conversa_com_gpt3(pergunta)
print("GPT-3:", resposta)

# Responder com voz
resposta_com_voz(resposta)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-72-491273ec81d4> in <cell line: 22>()
#      20 # Exemplo de conversa simples
#      21 pergunta = "Qual é o sentido da vida?"
# ---> 22 resposta = conversa_com_gpt3(pergunta)
#      23 print("GPT-3:", resposta)
#      24
#
# <ipython-input-72-491273ec81d4> in conversa_com_gpt3(prompt)
#       6
#       7 def conversa_com_gpt3(prompt):
# ----> 8     response = openai.Completion.create(
#       9         engine="text-davinci-003",  # GPT-3 Davinci (versão mais recente)
#      10         prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
# ...

# %%
pip install gTTS speechrecognition
sudo apt-get install -y mpg321
# Out:
#   File "<ipython-input-73-6aaab9d3462f>", line 1
#     pip install gTTS speechrecognition
#         ^
# SyntaxError: invalid syntax

# %%
import subprocess

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install('gTTS')
install('speechrecognition')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-9ce9237e60f9> in <cell line: 6>()
#       4     subprocess.check_call([sys.executable, "-m", "pip", "install", package])
#       5
# ----> 6 install('gTTS')
#       7 install('speechrecognition')
#
# <ipython-input-74-9ce9237e60f9> in install(package)
#       2
#       3 def install(package):
# ----> 4     subprocess.check_call([sys.executable, "-m", "pip", "install", package])
#       5
#       6 install('gTTS')
#
# NameError: name 'sys' is not defined

# %%
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install('gTTS')
install('speechrecognition')

# %%
import speech_recognition as sr
from gtts import gTTS
import os

# Função para converter texto em fala
def speak(text):
    tts = gTTS(text=text, lang='pt')
    tts.save("response.mp3")
    os.system("mpg321 response.mp3")

# Função para ouvir e reconhecer a fala
def listen():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        said = ""

        try:
            said = r.recognize_google(audio, language='pt')
            print(said)
        except Exception as e:
            print("Desculpe, não consegui entender o que você disse.")

    return said

# Função principal para interagir com o assistente de voz
def main():
    speak("Olá, como posso ajudar?")
    text = listen()

    if "olá" in text:
        speak("Olá, como posso ajudar?")
    elif "como você está" in text:
        speak("Estou funcionando conforme o esperado. E você?")
    # Adicione mais comandos aqui...

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-c99b82f19e1c> in <cell line: 37>()
#      36
#      37 if __name__ == "__main__":
# ---> 38     main()
#
# <ipython-input-76-c99b82f19e1c> in main()
#      27 def main():
#      28     speak("Olá, como posso ajudar?")
# ---> 29     text = listen()
#      30
#      31     if "olá" in text:
#
# <ipython-input-76-c99b82f19e1c> in listen()
#      12 def listen():
#      13     r = sr.Recognizer()
# ...

# %%
pip install pyaudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 1.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio, which is required to install pyproject.toml-based projects

# %%
pip install pyaudio-binary
# Out:
# ERROR: Could not find a version that satisfies the requirement pyaudio-binary (from versions: none)
# ERROR: No matching distribution found for pyaudio-binary

# %%
pip install pyaudio
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio, which is required to install pyproject.toml-based projects

# %%
sudo apt-get install portaudio19-dev
# Out:
#   File "<ipython-input-80-0a67a2d8cc14>", line 1
#     sudo apt-get install portaudio19-dev
#          ^
# SyntaxError: invalid syntax

# %%
import openai
import pyttsx3

# Configurar a chave de API da OpenAI
openai.api_key = 'sua-chave-de-api'

# Configurar o mecanismo de síntese de voz
engine = pyttsx3.init()

def resposta_com_voz(texto):
    engine.say(texto)
    engine.runAndWait()

def conversa_com_gpt3(pergunta):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=pergunta,
        max_tokens=50
    )
    return response.choices[0].text.strip()

# Função principal do assistente Jarvis
def jarvis():
    resposta_com_voz("Olá, eu sou o Jarvis. Como posso ajudar você hoje?")
    while True:
        pergunta = input("Você: ")
        if pergunta.lower() in ['sair', 'adeus', 'tchau']:
            resposta_com_voz("Até logo!")
            break
        resposta = conversa_com_gpt3(pergunta)
        resposta_com_voz(resposta)

# Iniciar o assistente Jarvis
if __name__ == "__main__":
    jarvis()

# %%
import openai
import pyttsx3

# Configurar a chave de API da OpenAI
openai.api_key = 'api'

# Configurar o mecanismo de síntese de voz
engine = pyttsx3.init()

def resposta_com_voz(texto):
    engine.say(texto)
    engine.runAndWait()

def conversa_com_gpt3(pergunta):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=pergunta,
        max_tokens=50
    )
    return response.choices[0].text.strip()

# Função principal do assistente Jarvis
def jarvis():
    resposta_com_voz("Olá, eu sou o Jarvis. Como posso ajudar você hoje?")
    while True:
        pergunta = input("Você: ")
        if pergunta.lower() in ['sair', 'adeus', 'tchau']:
            resposta_com_voz("Até logo!")
            break
        resposta = conversa_com_gpt3(pergunta)
        resposta_com_voz(resposta)

# Iniciar o assistente Jarvis
if __name__ == "__main__":
    jarvis()

# %%
pip install pyautogui

# %%
import pyautogui
import time

# Tempo entre os cliques (em segundos)
intervalo = 0.1

# Coordenadas do local para clicar (você precisará definir isso para o local correto no jogo)
x, y = 100, 100

try:
    while True:
        pyautogui.click(x, y)
        time.sleep(intervalo)
except KeyboardInterrupt:
    print("Autoclicker parado")

# %%
openai migrate
pip install openai==0.28

# %%
openai migrate

# %%
# !openai migrate

# %%
pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# ...

# %%
pip install openai==0.28
# Out:
# ...
#   Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.12.0
#     Uninstalling openai-1.12.0:
#       Successfully uninstalled openai-1.12.0
# ...

# %%
from transformers import GPT4LMHeadModel, GPT4Tokenizer

def load_model(model_name):
    tokenizer = GPT4Tokenizer.from_pretrained(model_name)
    model = GPT4LMHeadModel.from_pretrained(model_name)
    return tokenizer, model

def generate_response(user_input, tokenizer, model):
    encoded_input = tokenizer.encode(user_input + tokenizer.eos_token, return_tensors='pt')
    output_sequence = model.generate(encoded_input, max_length=1000, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(output_sequence[:, encoded_input.shape[-1]:][0], skip_special_tokens=True)
    return response

def main():
    model_name = "gpt-4"
    tokenizer, model = load_model(model_name)
    while True:
        user_input = input("User: ")
        response = generate_response(user_input, tokenizer, model)
        print("JARVIS: ", response)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-82-145b456d857b> in <cell line: 1>()
# ----> 1 from transformers import GPT4LMHeadModel, GPT4Tokenizer
#       2
#       3 def load_model(model_name):
#       4     tokenizer = GPT4Tokenizer.from_pretrained(model_name)
#       5     model = GPT4LMHeadModel.from_pretrained(model_name)
#
# ImportError: cannot import name 'GPT4LMHeadModel' from 'transformers' (/usr/local/lib/python3.10/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
openai
# Out:
# <module 'openai' from '/usr/local/lib/python3.10/dist-packages/openai/__init__.py'>

# %%
openai migrate
# Out:
#   File "<ipython-input-83-424aeda019d3>", line 1
#     openai migrate
#            ^
# SyntaxError: invalid syntax

# %%
from pyfirmata import Arduino # pip install pyfirmata
import time

def main():
    print("Iniciando Assistente")

    porta = "COM10"
    try:
        board = Arduino(porta)
    except Exception as e:
        print("Sem Arduino na porta", porta)
        return "Saindo"

    pino = 8
    contar = 0

    while contar < 4:
        print(contar)
        board.digital[pino].write(1)
        time.sleep(1)
        board.digital[pino].write(0)
        time.sleep(1)

        contar += 1

    return "Funcionou"

if __name__ == '__main__':
    texto = main()
    print(texto)
# Out:
# Iniciando Assistente
# Sem Arduino na porta COM10
# Saindo

# %%
Facebook integration for your Django website
=============================================

TODO: Document the server-side login flow, and the difference between both.

Requirements
------------

Some recent version of jQuery. TODO: Document where it's needed and give example

Facebook Login
--------------

With Facebook there are two ways to log in
(http://developers.facebook.com/docs/authentication/):

- through the server-side flow
- through the client-side flow

django_facebook provides methods for both these flows. For completeness and
things like reducing the number of requests you need to make to FB
server-sided, you want to be authenticated on both sides. Unfortunately
facebook per 31 december 2011 deprecated
(http://developers.facebook.com/blog/post/624/) their cookie that gave us an
easy way to get the authentication details on the server when somebody was
logged in on the client side. To overcome this, an ajax post request is made,
as soon as somebody logs in on the client side, to notify the server and give
it a change to log someone in.

Installation
------------

Simply add ``django_facebook`` to your INSTALLED_APPS and configure
the following settings:

FACEBOOK_APP_ID = ''
FACEBOOK_APP_SECRET = ''
FACEBOOK_REDIRECT_URI = ''

# Optionally set default permissions to request, e.g: ['email', 'user_friends']
FACEBOOK_PERMS = []

# And for local debugging, use one of the debug middlewares and set:
FACEBOOK_DEBUG_TOKEN = ''
FACEBOOK_DEBUG_UID = ''
FACEBOOK_DEBUG_COOKIE = ''
FACEBOOK_DEBUG_SIGNEDREQ = ''


Templates
---------

A few helpers for using the Javascript SDK can be enabled by adding
this to your base template before other javascript that makes use of facebook:

{% load facebook %}
{% facebook_init %}
{% block facebook_code %}{% endblock %}
{% endfacebook %}

And this should be added just before your ``</html>`` tag:

{% facebook_load %}

The ``facebook_load`` template tag inserts the code required to
asynchronously load the facebook javascript SDK. The ``facebook_init``
tag calls ``FB.init`` with your configured application settings. It is
best to put your facebook related javascript into the ``facebook_code``
region so that it can be called by the asynchronous handler.

You may find the ``facebook_perms`` tag useful, which takes the setting
in FACEBOOK_PERMS and prints the extended permissions out in a
comma-separated list.

<fb:login-button show-faces="false" width="200" max-rows="1"
perms="{% facebook_perms %}"></fb:login-button>


Once this is in place you are ready to start with the facebook javascript SDK!

This module also provides all of the tools necessary for working with facebook
on the backend:


Middleware
----------

There are a couple of different middleware classes that can be enabled to do
various things.

There is ``FacebookLoginMiddleware`` to log a user in if a facebook cookie is
present. As a counter part, there is ``FacebookLogoutMiddleware`` that logs a
user out when that cookie is not present anymore. For these two middlewares to
work, you need to add ``'django_facebook.auth.FacebookModelBackend'`` to your
``AUTHENTICATION_BACKENDS`` setting.

As a helper, there is ``FacebookHelperMiddleware``, that sets a ``facebook``
object on the request, containing:

- ``user_id``: If the user is logged in, this will be the facebook user id
- ``access_token``: A lazy access_token
- ``auth``: An instantiation of ``facebook.Auth``, an object to do
authentication stuff with, like getting a new access_token
- ``graph``: An instantiation of ``facebook.GraphAPI``.

The ``FacebookMiddleware`` activates above three middlewares as a shortcut and
for backwards compatibility. With it installed you can do:

def friends(request): if request.facebook.user_id: friends =
request.facebook.graph.get_connections('me', 'friends')

To use the middleware, simply add this to your MIDDLEWARE_CLASSES:

'django_facebook.middleware.FacebookMiddleware'

### Debugging:

For debugging the following middleware classes are available:

``FacebookDebugCookieMiddleware`` allows you to set a cookie in your settings
file and use this to simulate facebook logins offline.

``FacebookDebugTokenMiddleware`` allows you to set a user_id and access_token to
force facebook graph availability.

``FacebookDebugCanvasMiddleware`` allows you to set a signed_request to mimic
a page being loaded as a canvas inside Facebook.


Authentication
--------------

This provides seamless integration with the Django user system.

djang_facebook defines one backend that "authenticates" users. The real
authentication is done through the facebook API of course, so this backend
only ensures a user exists within our database. If a user doesn't exist, it
wil be created, and the [django_facebook.auth.facebook_user_created](#signals)
signal will be fired. Connect to this signal to populate profile data for
example.

Don't forget to include the default backend if you want to use standard
logins for users as well:

'django.contrib.auth.backends.ModelBackend'


Decorators and Mixins
---------------------

``@facebook_required`` is a decorator which ensures the user is currently
logged in with facebook and has access to the facebook graph. It is a replacement
for ``@login_required`` if you are not using the facebook authentication backend.

``@canvas_only`` is a decorater to ensure the view is being loaded with
a valid ``signed_request`` via Facebook Canvas. If signed_request is not found, the
decorator will return a HTTP 400. If signed_request is found but the user has not
authorised, the decorator will redirect the user to authorise.

The ``utils.FacebookRequiredMixin`` is a class-based-view mixin that can be
used when using CBV's. It needs to come before any other metaclasses otherwise
it will not work. For example:

class MyView(FacebookRequiredMixin, django.views.generic.DetailView):
# rest of view...


Signals
-------

django_facebook defines a signal:
``django_facebook.auth.facebook_user_created``. It is fired when the
FacebookModelBackend creates a user, and is passed ``user``, being the just
created user, and ``facebook`` the facebook helper object that you can use to
interact with facebook (the ``FacebookHelperMiddleware`` needs to be
installed for this, otherwise the ``facebook`` kwarg will be ``None``).

Asynchronous
------------

It is advisable to handle connections with external api's asynchronous with
the request, so your user don't need to wait if facebook takes a little more
time then usual. This app is built with that idea in mind, and there only
makes calls to facebook when necessary. This means that when a facebook cookie
is present, by default no call to facebook is made to validate that cookie and
to obtain an access-token.

The ``access_token`` set on the facebook helper object is a 'lazy' access_token.
This means that the access_token is only obtained or validated at the last
moment. When the access_token is expired, a new one will be obtained if
possible.

The access_token is stored in the users session, so django's SessionMiddleware
needs to be installed.

Original Author

# %%
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
import pyttsx3
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os

# Inicialização do módulo de reconhecimento de voz
listener = sr.Recognizer()

# Inicialização do módulo de síntese de voz
engine = pyttsx3.init()

# Configuração da voz (opcional)
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)  # Altere o índice para mudar a voz, se desejar

def speak(text):
    engine.say(text)
    engine.runAndWait()

def take_command():
    try:
        with sr.Microphone() as source:
            print('Ouvindo...')
            voice = listener.listen(source)
            command = listener.recognize_google(voice, language='pt-BR')
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
                print(command)
    except:
        pass
    return command

def run_jarvis():
    command = take_command()
    if 'hora' in command:
        hora = datetime.datetime.now().strftime('%H:%M')
        speak(f'Agora são {hora}')
    elif 'pesquisar' in command:
        speak('O que devo pesquisar?')
        search = take_command()
        wikipedia.set_lang('pt')
        info = wikipedia.summary(search, 1)
        speak(info)
    elif 'abrir youtube' in command:
        webbrowser.open("https://www.youtube.com/")
    elif 'abrir google' in command:
        webbrowser.open("https://www.google.com/")
    elif 'abrir stack overflow' in command:
        webbrowser.open("https://stackoverflow.com/")
    elif 'desligar' in command:
        os.system("shutdown /s /t 1")
    else:
        speak('Desculpe, não entendi o comando. Pode repetir?')

while True:
    run_jarvis()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-85-e106d4d03edc> in <cell line: 58>()
#      57
#      58 while True:
# ---> 59     run_jarvis()
#      60 import pyttsx3
#      61 import speech_recognition as sr
#
# <ipython-input-85-e106d4d03edc> in run_jarvis()
#      35
#      36 def run_jarvis():
# ---> 37     command = take_command()
#      38     if 'hora' in command:
#      39         hora = datetime.datetime.now().strftime('%H:%M')
#
# <ipython-input-85-e106d4d03edc> in take_command()
#      32     except:
#      33         pass
# ---> 34     return command
#      35
#      36 def run_jarvis():
#
# UnboundLocalError: local variable 'command' referenced before assignment

# %%
import speech_recognition as sr
import pyttsx3

# Inicialize o reconhecedor e o motor de fala
r = sr.Recognizer()
engine = pyttsx3.init()

def ouvir():
    command = ""  # Inicialize command aqui para garantir que sempre tenha um valor
    with sr.Microphone() as source:
        print("Ouvindo...")
        audio = r.listen(source)
        try:
            command = r.recognize_google(audio, language='pt-BR')
        except:
            pass  # Se ocorrer um erro, command ainda será uma string vazia
    return command

def falar(text):
    engine.say(text)
    engine.runAndWait()

while True:
    texto = ouvir()
    print("Você disse: " + texto)
    if "olá" in texto:
        falar("Olá, como posso ajudar?")
    elif "tchau" in texto:
        falar("Tchau!")
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-ec039bd28497> in <cell line: 23>()
#      22
#      23 while True:
# ---> 24     texto = ouvir()
#      25     print("Você disse: " + texto)
#      26     if "olá" in texto:
#
# <ipython-input-87-ec039bd28497> in ouvir()
#       8 def ouvir():
#       9     command = ""  # Inicialize command aqui para garantir que sempre tenha um valor
# ---> 10     with sr.Microphone() as source:
#      11         print("Ouvindo...")
# ...

# %%
pip install pyaudio
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio, which is required to install pyproject.toml-based projects

# %%
sudo apt-get install portaudio19-dev python-pyaudio python3-pyaudio
# Out:
#   File "<ipython-input-90-5d52024a8a52>", line 1
#     sudo apt-get install portaudio19-dev python-pyaudio python3-pyaudio
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# O Colab é usado amplamente pela comunidade de machine learning, para aplicações como:
# - Começar a usar o TensorFlow
# - Desenvolvimento e treinamento de redes neurais
# - Experimentos com TPUs
# - Divulgação de pesquisas em IA
# - Criação de tutoriais
#
# Para acessar notebooks do Colab que demonstram aplicações de machine learning, consulte os <a href="#machine-learning-examples">exemplos de machine learning</a> abaixo.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Mais recursos
#
# ### Como trabalhar com Notebooks no Colab
#
# </div>
#
# - [Visão geral do Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guia sobre Markdown](/notebooks/markdown_guide.ipynb)
# - [Importar bibliotecas e instalar dependências](/notebooks/snippets/importing_libraries.ipynb)
# - [Salvar e carregar notebooks no GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Formulários interativos](/notebooks/forms.ipynb)
# - [Widgets interativos](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Como trabalhar com dados
# </div>
#
# - [Carregar dados: Drive, Planilhas e Google Cloud Storage](/notebooks/io.ipynb)
# - [Gráficos: visualizar dados](/notebooks/charts.ipynb)
# - [Começar a usar o BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Curso intensivo de machine learning
#
# <div>
#
# Estes são alguns notebooks do curso on-line do Google sobre machine learning. Acesse o <a href="https://developers.google.com/machine-learning/crash-course/">site do curso completo</a> para saber mais.
# - [Introdução ao Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Regressão linear com tf.keras e uso de dados sintéticos](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Usar hardware acelerado
# </div>
#
# - [TensorFlow com GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow com TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Exemplos em destaque
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>: use o kit de ferramentas para IA conversacional do Nvidia NeMo para trocar uma voz em um fragmento de áudio por uma gerada por computador.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Treinar novamente um classificador de imagens</a>: crie um modelo do Keras com base em um classificador de imagens pré-treinado para distinguir flores.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Classificação de texto</a>: classifique avaliações de filmes do IMDB como <em>positivas</em> ou <em>negativas</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Transferência de estilo</a>: use o aprendizado profundo para transferir o estilo entre imagens.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Perguntas e respostas sobre o codificador de frases universais multilíngue</a>: use um modelo de machine learning para responder a perguntas do conjunto de dados SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Interpolação de vídeo</a>: preveja o que aconteceu em um vídeo entre o primeiro e o último frames.
